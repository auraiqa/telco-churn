# %% [markdown]
# 🎯 Problem Statement (Latar Belakang Masalah)
#
# Berdasarkan data pelanggan yang tersedia, terlihat bahwa angka customer churn pada perusahaan telekomunikasi ini masih cukup tinggi.
# Untuk mendukung strategi bisnis yang lebih tepat sasaran, penting untuk memahami karakteristik pelanggan yang cenderung melakukan churn serta faktor-faktor yang berpotensi memengaruhinya.

# %%
import pandas as pd
df = pd.read_csv("Telco Customer Churn.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
import seaborn as sns
sns.countplot(data=df, x='Churn')
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.histplot(data=df, x='tenure', hue='Contract', multiple='stack', bins=30)
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %%
pd.crosstab(df['Contract'], df['Churn'], normalize='index')
# Out:
# Churn                 No       Yes
# Contract
# Month-to-month  0.572903  0.427097
# One year        0.887305  0.112695
# Two year        0.971681  0.028319

# %%
sns.histplot(data=df, x='tenure', hue='Churn', multiple='stack', bins=30)
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %%
sns.boxplot(data=df, x='Churn', y='MonthlyCharges')
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharges'>

# %%
sns.countplot(data=df, x='InternetService', hue='Churn')
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %%
sns.countplot(data=df, x='SeniorCitizen', hue='Churn')
# Out:
# <Axes: xlabel='SeniorCitizen', ylabel='count'>

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >
